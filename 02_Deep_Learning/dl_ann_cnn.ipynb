# %% [markdown]
# # Deep Learning Suite: ANN (Sensors) & CNN (Computer Vision)
#
# This notebook demonstrates deep learning architecture implementations in **PyTorch**:
# 1. **ANN (Artificial Neural Network)**: Multi-layer Perceptron for Industrial Sensor Vitals & Failure Risk Diagnosis.
# 2. **CNN (Convolutional Neural Network)**: Deep 2D Convolutional network with Batch Normalization, Max Pooling, and Data Augmentation for Visual Surface Defect Classification.

# %%
import os
import torch
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

from train_models import train_ann_model, train_cnn_model

print("PyTorch Version:", torch.__version__)
print("CUDA Available:", torch.cuda.is_available())

# %% [markdown]
# ## 1. Train ANN Model (Machine Vitals)

# %%
train_ann_model()

# %% [markdown]
# ## 2. Train CNN Model (Surface Defect Vision)

# %%
train_cnn_model()

# %% [markdown]
# ## 3. Display Loss & Accuracy Training Curves

# %%
if os.path.exists('models/ann_training_curves.png'):
    img_ann = Image.open('models/ann_training_curves.png')
    plt.figure(figsize=(8, 4))
    plt.imshow(img_ann)
    plt.axis('off')
    plt.title('ANN Training History')
    plt.show()

if os.path.exists('models/cnn_training_curves.png'):
    img_cnn = Image.open('models/cnn_training_curves.png')
    plt.figure(figsize=(8, 4))
    plt.imshow(img_cnn)
    plt.axis('off')
    plt.title('CNN Training History')
    plt.show()
